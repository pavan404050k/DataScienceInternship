# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') 

from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv("C:\\Users\\spava\\Downloads\\Google Stocks.csv")
df.head(10)
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %%
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
df = df[['date','open','close']]
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0]))
df.set_index('date',drop=True,inplace=True)
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %%
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
training_size = round(len(df) * 0.75)
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)):
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data) 
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %%
model = Sequential() 
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 5s 55ms/step - loss: 0.0113 - mean_absolute_error: 0.0768 - val_loss: 0.0315 - val_mean_absolute_error: 0.1567
# Epoch 2/100
# 28/28 [==============================] - 1s 27ms/step - loss: 0.0011 - mean_absolute_error: 0.0270 - val_loss: 0.0031 - val_mean_absolute_error: 0.0433
# Epoch 3/100
# 28/28 [==============================] - 1s 28ms/step - loss: 4.6485e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0015 - val_mean_absolute_error: 0.0311
# Epoch 4/100
# 28/28 [==============================] - 1s 29ms/step - loss: 4.5221e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0029 - val_mean_absolute_error: 0.0425
# Epoch 5/100
# 28/28 [==============================] - 1s 31ms/step - loss: 4.5037e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0030 - val_mean_absolute_error: 0.0426
# Epoch 6/100
# 28/28 [==============================] - 1s 31ms/step - loss: 4.3414e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0030 - val_mean_absolute_error: 0.0428
# Epoch 7/100
# 28/28 [==============================] - 1s 31ms/step - loss: 4.3977e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0021 - val_mean_absolute_error: 0.0346
# Epoch 8/100
# 28/28 [==============================] - 1s 33ms/step - loss: 3.7626e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0018 - val_mean_absolute_error: 0.0322
# Epoch 9/100
# 28/28 [==============================] - 1s 33ms/step - loss: 3.7652e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0029 - val_mean_absolute_error: 0.0414
# Epoch 10/100
# 28/28 [==============================] - 1s 33ms/step - loss: 3.6671e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0038 - val_mean_absolute_error: 0.0491
# Epoch 11/100
# 28/28 [==============================] - 1s 33ms/step - loss: 3.6148e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0050 - val_mean_absolute_error: 0.0577
# Epoch 12/100
# 28/28 [==============================] - 1s 35ms/step - loss: 3.7833e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0038 - val_mean_absolute_error: 0.0467
# Epoch 13/100
# 28/28 [==============================] - 1s 31ms/step - loss: 3.5767e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0063 - val_mean_absolute_error: 0.0648
# Epoch 14/100
# 28/28 [==============================] - 1s 34ms/step - loss: 3.5057e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0043 - val_mean_absolute_error: 0.0511
# Epoch 15/100
# 28/28 [==============================] - 1s 36ms/step - loss: 3.1114e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0048 - val_mean_absolute_error: 0.0532
# Epoch 16/100
# 28/28 [==============================] - 1s 33ms/step - loss: 3.2898e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0082 - val_mean_absolute_error: 0.0747
# Epoch 17/100
# 28/28 [==============================] - 1s 31ms/step - loss: 3.3280e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0079 - val_mean_absolute_error: 0.0717
# Epoch 18/100
# 28/28 [==============================] - 1s 32ms/step - loss: 3.6497e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0068 - val_mean_absolute_error: 0.0645
# Epoch 19/100
# 28/28 [==============================] - 1s 33ms/step - loss: 3.1478e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0050 - val_mean_absolute_error: 0.0538
# Epoch 20/100
# 28/28 [==============================] - 1s 31ms/step - loss: 3.2034e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0082 - val_mean_absolute_error: 0.0715
# Epoch 21/100
# 28/28 [==============================] - 1s 33ms/step - loss: 2.8335e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0082 - val_mean_absolute_error: 0.0714
# Epoch 22/100
# 28/28 [==============================] - 1s 32ms/step - loss: 2.9719e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0083 - val_mean_absolute_error: 0.0701
# Epoch 23/100
# 28/28 [==============================] - 1s 31ms/step - loss: 2.9998e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0078 - val_mean_absolute_error: 0.0689
# Epoch 24/100
# 28/28 [==============================] - 1s 32ms/step - loss: 2.7366e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0078 - val_mean_absolute_error: 0.0685
# Epoch 25/100
# 28/28 [==============================] - 1s 32ms/step - loss: 2.6267e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0109 - val_mean_absolute_error: 0.0829
# Epoch 26/100
# 28/28 [==============================] - 1s 32ms/step - loss: 3.1448e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0103 - val_mean_absolute_error: 0.0814
# Epoch 27/100
# 28/28 [==============================] - 1s 32ms/step - loss: 2.8983e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0055 - val_mean_absolute_error: 0.0555
# Epoch 28/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.5514e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0076 - val_mean_absolute_error: 0.0652
# Epoch 29/100
# 28/28 [==============================] - 1s 29ms/step - loss: 2.6020e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0114 - val_mean_absolute_error: 0.0841
# Epoch 30/100
# 28/28 [==============================] - 1s 29ms/step - loss: 2.7343e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0064 - val_mean_absolute_error: 0.0581
# Epoch 31/100
# 28/28 [==============================] - 1s 28ms/step - loss: 2.5400e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0113 - val_mean_absolute_error: 0.0806
# Epoch 32/100
# 28/28 [==============================] - 1s 27ms/step - loss: 2.6046e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0088 - val_mean_absolute_error: 0.0676
# Epoch 33/100
# 28/28 [==============================] - 1s 27ms/step - loss: 2.5503e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0093 - val_mean_absolute_error: 0.0694
# Epoch 34/100
# 28/28 [==============================] - 1s 28ms/step - loss: 2.3792e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0108 - val_mean_absolute_error: 0.0753
# Epoch 35/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.5174e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0156 - val_mean_absolute_error: 0.0944
# Epoch 36/100
# 28/28 [==============================] - 1s 31ms/step - loss: 2.3984e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0113 - val_mean_absolute_error: 0.0782
# Epoch 37/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.4637e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0093 - val_mean_absolute_error: 0.0684
# Epoch 38/100
# 28/28 [==============================] - 1s 34ms/step - loss: 2.8405e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0062 - val_mean_absolute_error: 0.0550
# Epoch 39/100
# 28/28 [==============================] - 1s 34ms/step - loss: 2.6036e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0062 - val_mean_absolute_error: 0.0548
# Epoch 40/100
# 28/28 [==============================] - 1s 32ms/step - loss: 2.6206e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0057 - val_mean_absolute_error: 0.0530
# Epoch 41/100
# 28/28 [==============================] - 1s 30ms/step - loss: 2.4247e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0077 - val_mean_absolute_error: 0.0645
# Epoch 42/100
# 28/28 [==============================] - 1s 34ms/step - loss: 2.3566e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0044 - val_mean_absolute_error: 0.0458
# Epoch 43/100
# 28/28 [==============================] - 1s 39ms/step - loss: 2.2171e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0059 - val_mean_absolute_error: 0.0528
# Epoch 44/100
# 28/28 [==============================] - 1s 38ms/step - loss: 2.4937e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0047 - val_mean_absolute_error: 0.0464
# Epoch 45/100
# 28/28 [==============================] - 1s 37ms/step - loss: 2.6263e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0036 - val_mean_absolute_error: 0.0423
# Epoch 46/100
# 28/28 [==============================] - 1s 38ms/step - loss: 2.1298e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0060 - val_mean_absolute_error: 0.0594
# Epoch 47/100
# 28/28 [==============================] - 1s 36ms/step - loss: 2.1202e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0049 - val_mean_absolute_error: 0.0502
# Epoch 48/100
# 28/28 [==============================] - 1s 32ms/step - loss: 2.3692e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0073 - val_mean_absolute_error: 0.0694
# Epoch 49/100
# 28/28 [==============================] - 1s 32ms/step - loss: 2.1246e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0048 - val_mean_absolute_error: 0.0495
# Epoch 50/100
# 28/28 [==============================] - 1s 35ms/step - loss: 2.0358e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0094 - val_mean_absolute_error: 0.0741
# Epoch 51/100
# 28/28 [==============================] - 1s 35ms/step - loss: 2.1363e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0033 - val_mean_absolute_error: 0.0407
# Epoch 52/100
# 28/28 [==============================] - 1s 33ms/step - loss: 1.9938e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0024 - val_mean_absolute_error: 0.0343
# Epoch 53/100
# 28/28 [==============================] - 1s 34ms/step - loss: 2.0625e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0022 - val_mean_absolute_error: 0.0328
# Epoch 54/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.9607e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0027 - val_mean_absolute_error: 0.0367
# Epoch 55/100
# 28/28 [==============================] - 1s 28ms/step - loss: 2.2066e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0024 - val_mean_absolute_error: 0.0342
# Epoch 56/100
# 28/28 [==============================] - 1s 31ms/step - loss: 2.1753e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0021 - val_mean_absolute_error: 0.0321
# Epoch 57/100
# 28/28 [==============================] - 1s 32ms/step - loss: 2.2775e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0030 - val_mean_absolute_error: 0.0389
# Epoch 58/100
# 28/28 [==============================] - 1s 34ms/step - loss: 2.1124e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0040 - val_mean_absolute_error: 0.0506
# Epoch 59/100
# 28/28 [==============================] - 1s 35ms/step - loss: 1.8538e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0026 - val_mean_absolute_error: 0.0370
# Epoch 60/100
# 28/28 [==============================] - 1s 35ms/step - loss: 1.8248e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0023 - val_mean_absolute_error: 0.0340
# Epoch 61/100
# 28/28 [==============================] - 1s 35ms/step - loss: 1.9218e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0038 - val_mean_absolute_error: 0.0482
# Epoch 62/100
# 28/28 [==============================] - 1s 35ms/step - loss: 1.7944e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0049 - val_mean_absolute_error: 0.0544
# Epoch 63/100
# 28/28 [==============================] - 1s 32ms/step - loss: 1.8516e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0023 - val_mean_absolute_error: 0.0353
# Epoch 64/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.7183e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0026 - val_mean_absolute_error: 0.0374
# Epoch 65/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.6725e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0027 - val_mean_absolute_error: 0.0390
# Epoch 66/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.6911e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0031 - val_mean_absolute_error: 0.0435
# Epoch 67/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.8402e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0019 - val_mean_absolute_error: 0.0328
# Epoch 68/100
# 28/28 [==============================] - 1s 29ms/step - loss: 1.7311e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0012 - val_mean_absolute_error: 0.0253
# Epoch 69/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.7178e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0035 - val_mean_absolute_error: 0.0458
# Epoch 70/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.6177e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0026 - val_mean_absolute_error: 0.0389
# Epoch 71/100
# 28/28 [==============================] - 1s 29ms/step - loss: 1.5735e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0035 - val_mean_absolute_error: 0.0458
# Epoch 72/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.5207e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0021 - val_mean_absolute_error: 0.0335
# Epoch 73/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.6433e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0014 - val_mean_absolute_error: 0.0268
# Epoch 74/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.7647e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0022 - val_mean_absolute_error: 0.0349
# Epoch 75/100
# 28/28 [==============================] - 1s 29ms/step - loss: 1.5249e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0021 - val_mean_absolute_error: 0.0345
# Epoch 76/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.4019e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0017 - val_mean_absolute_error: 0.0300
# Epoch 77/100
# 28/28 [==============================] - 1s 34ms/step - loss: 1.4913e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0017 - val_mean_absolute_error: 0.0303
# Epoch 78/100
# 28/28 [==============================] - 1s 34ms/step - loss: 1.5726e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0015 - val_mean_absolute_error: 0.0282
# Epoch 79/100
# 28/28 [==============================] - 1s 35ms/step - loss: 1.4701e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0024 - val_mean_absolute_error: 0.0364
# Epoch 80/100
# 28/28 [==============================] - 1s 35ms/step - loss: 1.4020e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0019 - val_mean_absolute_error: 0.0320
# Epoch 81/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.3498e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0027 - val_mean_absolute_error: 0.0408
# Epoch 82/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.3812e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0020 - val_mean_absolute_error: 0.0330
# Epoch 83/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.3884e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0012 - val_mean_absolute_error: 0.0247
# Epoch 84/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.4232e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0017 - val_mean_absolute_error: 0.0305
# Epoch 85/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.6784e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0027 - val_mean_absolute_error: 0.0404
# Epoch 86/100
# 28/28 [==============================] - 1s 32ms/step - loss: 1.3285e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0015 - val_mean_absolute_error: 0.0287
# Epoch 87/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.4977e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0010 - val_mean_absolute_error: 0.0230
# Epoch 88/100
# 28/28 [==============================] - 1s 33ms/step - loss: 1.4799e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0019 - val_mean_absolute_error: 0.0341
# Epoch 89/100
# 28/28 [==============================] - 1s 32ms/step - loss: 1.5128e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0019 - val_mean_absolute_error: 0.0340
# Epoch 90/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.3433e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0016 - val_mean_absolute_error: 0.0305
# Epoch 91/100
# 28/28 [==============================] - 1s 32ms/step - loss: 1.3258e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0012 - val_mean_absolute_error: 0.0248
# Epoch 92/100
# 28/28 [==============================] - 1s 32ms/step - loss: 1.2439e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0013 - val_mean_absolute_error: 0.0264
# Epoch 93/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.3360e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0012 - val_mean_absolute_error: 0.0252
# Epoch 94/100
# 28/28 [==============================] - 1s 33ms/step - loss: 1.2767e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0016 - val_mean_absolute_error: 0.0296
# Epoch 95/100
# 28/28 [==============================] - 1s 39ms/step - loss: 1.4345e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0015 - val_mean_absolute_error: 0.0278
# Epoch 96/100
# 28/28 [==============================] - 1s 39ms/step - loss: 1.2803e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0020 - val_mean_absolute_error: 0.0346
# Epoch 97/100
# 28/28 [==============================] - 1s 40ms/step - loss: 1.2840e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0016 - val_mean_absolute_error: 0.0293
# Epoch 98/100
# 28/28 [==============================] - 1s 39ms/step - loss: 1.2381e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0016 - val_mean_absolute_error: 0.0297
# Epoch 99/100
# 28/28 [==============================] - 1s 38ms/step - loss: 1.1235e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0015 - val_mean_absolute_error: 0.0300
# Epoch 100/100
# 28/28 [==============================] - 1s 33ms/step - loss: 1.2545e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 1s 10ms/step
# array([[0.40394342, 0.40808418],
#        [0.40415308, 0.4086786 ],
#        [0.40091762, 0.4058874 ],
#        [0.4022933 , 0.40714315],
#        [0.4049918 , 0.40965483]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1419.8788, 1424.5787],
#        [1420.2675, 1425.6804],
#        [1414.2692, 1420.5073],
#        [1416.8196, 1422.8347],
#        [1421.8224, 1427.4896]], dtype=float32)

# %%
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1419.878784      1424.578735
# 2020-05-28  1396.86  1416.73     1420.267456      1425.680420
# 2020-05-29  1416.94  1428.92     1414.269165      1420.507324
# 2020-06-01  1418.39  1431.82     1416.819580      1422.834717
# 2020-06-02  1430.55  1439.22     1421.822388      1427.489624

# %%
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2414.948730      2349.624023
# 2021-06-10  2494.01  2521.60     2428.275635      2361.933838
# 2021-06-11  2524.92  2513.93     2439.606201      2371.825684
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()
